# %%
from src.constants import ISO3S
from src.datasources import ipc

df_ipc_raw = ipc.get_reports(filter_iso3s=list(ISO3S.values()))
df_ipc_classified = ipc.classify_reports(df_ipc_raw)

# %%
df_ipc_classified
# Out:
#     location_code          ipc_type  population_analyzed       From  \
# 0             AGO           current               903937 2019-07-01
# 2             AGO  first projection               903937 2019-10-01
# 1             AGO           current              2667790 2021-06-01
# 3             AGO  first projection              2750124 2021-10-01
# 4             BDI           current              9758864 2017-04-01
# ..            ...               ...                  ...        ...
# 257           ZWE           current              9420663 2019-06-01
# 260           ZWE  first projection              9420663 2019-10-01
# 258           ZWE           current              9706118 2020-02-01
# 259           ZWE           current              9706118 2020-10-01
# 261           ZWE  first projection              9706118 2021-01-01
#
#                      To  year  proportion_3+  proportion_4+  population_3+  \
# 0   2019-09-30 23:59:59  2019           0.47           0.25         421167
# 2   2020-02-29 23:59:59  2020           0.62           0.32         561836
# 1   2021-09-30 23:59:59  2021           0.49           0.12        1315532
# 3   2022-03-31 23:59:59  2022           0.58           0.15        1583996
# 4   2017-05-31 23:59:59  2017           0.26           0.07        2565868
# ..                  ...   ...            ...            ...            ...
# 257 2019-09-30 23:59:59  2019           0.25           0.07        2294605
# 260 2019-12-31 23:59:59  2019           0.38           0.12        3580214
# 258 2020-06-30 23:59:59  2020           0.45           0.11        4341420
# 259 2020-12-31 23:59:59  2020           0.27           0.06        2605477
# 261 2021-03-31 23:59:59  2021           0.35           0.08        3380232
#
#      population_4+  pop_comparable  pt_change_3+  pt_change_4+ alert_level  \
# 0           221609           False             0             0        high
# 2           290229            True            15             7   very high
# 1           307288           False             0             0        high
# 3           416660            True             9             3   very high
# 4           701117           False             0             0   very high
# ..             ...             ...           ...           ...         ...
# 257         623138            True            -5            -3   very high
# 260        1105458            True            13             5   very high
# 258        1047085            True             7            -1   very high
# 259         588235            True           -18            -5   very high
# 261         768594            True             8             2   very high
#
#     alert_level_detail
# 0            emergency
# 2        deteriorating
# 1            emergency
# 3        deteriorating
# 4            emergency
# ..                 ...
# 257          emergency
# 260       all criteria
# 258          emergency
# 259          emergency
# 261          emergency
#
# [262 rows x 15 columns]
